# %%
# import necessary packages
import numpy as np
import torch
import matplotlib.pyplot as plt
import math
torch.set_default_dtype(torch.float64) # set arithmetic to be double precision
plt.rcParams.update({'font.size': 10}) # set font size in all plots

# %%
def ExactSolution(x,y):
    # y^{2} * sin(pi*x)
    return y**2 * torch.sin(math.pi * x)

# %%
def prepare_data(xmin,xmax,nx,ymin,ymax,ny,strip_bdry):
    x1 = torch.linspace(xmin,xmax,steps = nx)
    y1 = torch.linspace(ymin,ymax,steps = ny)
    if strip_bdry == True:
        grid_x, grid_y = torch.meshgrid(x1[1:nx-1],y1[1:ny-1],indexing = 'ij')
    else:
        grid_x, grid_y = torch.meshgrid(x1,y1,indexing = 'ij')
    xcol = torch.reshape(grid_x,(grid_x.numel(),1))
    ycol = torch.reshape(grid_y,(grid_y.numel(),1))
    data_matrix = torch.cat((xcol,ycol),1)
    return grid_x, grid_y, data_matrix

# %%
# define training points
npt1 = 9
strip_boundary = True
xtrain_grid, ytrain_grid, xytrain = prepare_data(0.,1.,npt1,0.,1.,npt1,strip_boundary)

# define test points
npt2 = 100
strip_boundary = False
xtest_grid, ytest_grid, xytest = prepare_data(0.,1.,npt2,0.,1.,npt2,strip_boundary)

# find the exact solution at the test points
sol_exact = ExactSolution(xtest_grid,ytest_grid)
sol_exact_vector = torch.reshape(sol_exact,(torch.numel(sol_exact),1))
sol_min = torch.min(sol_exact_vector)
sol_max = torch.max(sol_exact_vector)

# plot the exact solution and the training points
plt.figure()
plt.contour(xtest_grid,ytest_grid,sol_exact,torch.arange(sol_min,sol_max,(sol_max-sol_min)*0.1))  
plt.scatter(xytrain[:,0],xytrain[:,1],s = 10, c = '#FF0000')
plt.colorbar()
plt.title("Exact sol. and train pts")
# Out:
# Text(0.5, 1.0, 'Exact sol. and train pts')

# %%
# define activation function
def ActiveFun(x):
    # tanh
    ActFun = torch.tanh(x);
    dActFun = 1/torch.cosh(x).pow(2); # 1./cosh(x).^2
    d2ActFun = -2*torch.sinh(x)/torch.cosh(x).pow(3); # -2*sinh(x)./cosh(x).^3
    d3ActFun = (4*torch.sinh(x).pow(2)-2)/torch.cosh(x).pow(4); # (4*sinh(x).^2-2)./cosh(x).^4
    d4ActFun = (16*torch.sinh(x)-8*torch.sinh(x).pow(3))/torch.cosh(x).pow(5); # (16*sinh(x)-8sinh(x).^3)./cosh(x).^5
    return ActFun, dActFun, d2ActFun, d3ActFun, d4ActFun

# %%
# define solution model
# define our model and call it model_11
N_neurons = 10
# initialize parameters of NN with random numbers
W = torch.rand(N_neurons*4,1)
# architecture: NN(X;w) = w3 * sigma(w0*x + w2*1 + w2)
# w3 is 1-by-N_neurons
# w2 is N_neurons-by-2
# w1 is Nneurons-by-1

def NeuralNetwork(x,y,W,derivatives):
    Nneurons = int((torch.numel(W)/4))
    # print("NN: Nneurons = ",Nneurons)
    W = torch.transpose(torch.reshape(W,(4,Nneurons)),0,1)
    z = W[:,2]+W[:,0]*x+W[:,1]*y # argument of sigma
    s0,s1,s2,s3,s4 = ActiveFun(z) # sigma(z) and its first three derivatives
    # the neural network and its derivatives with respect to x and y
    W3s1 = W[:,3]*s1;
    NN = torch.sum(W[:,3]*s0)
    if derivatives == False:
        return NN
    else:    
        NNx = torch.sum(W3s1*W[:,0])
        NNy = torch.sum(W3s1*W[:,1])
        NNxx = torch.sum(W[:,3]*(W[:,0].pow(2)*s2))
        NNyy = torch.sum(W[:,3]*(W[:,1].pow(2)*s2))
        NNxy = torch.sum(W[:,3]*(W[:,0]*W[:,1]*s2))
        NNxxy = torch.sum(W[:,3]*(W[:,0].pow(2)*W[:,1]*s3))
        # derivatives w.r.t. parameters of the neural network 
        NN_W0 = x*W3s1
        NN_W1 = y*W3s1
        NN_W2 = W3s1
        NN_W3 = s0
        NN_W = torch.cat((NN_W0,NN_W1,NN_W2,NN_W3),0) # combine derivatives into a column vector    
        # derivatives w.r.t. parameters of NNx = sum(w3*w0*s1)
        W3W0s2 = W[:,3]*W[:,0]*s2;
        NNx_W0 = W3s1 + W3W0s2*x
        NNx_W1 = W3W0s2*y
        NNx_W2 = W3W0s2
        NNx_W3 = W[:,0]*s1
        NNx_W = torch.cat((NNx_W0,NNx_W1,NNx_W2,NNx_W3),0) # combine derivatives into a column vector
        # derivatives w.r.t. parameters of NNy = sum(w3*w1*s1)
        W3W1s2 = W[:,3]*W[:,1]*s2;
        NNy_W0 = W3W1s2*x
        NNy_W1 = W3s1 + W3W1s2*y
        NNy_W2 = W3W1s2
        NNy_W3 = W[:,1]*s1
        NNy_W = torch.cat((NNy_W0,NNy_W1,NNy_W2,NNy_W3),0) # combine derivatives into a column vector
        # derivatives w.r.t. parameters of NNxy = sum(w3*w1*s1)
        W3W1W0s3 = W[:,3]*W[:,1]*s2
        NNxy_W0 = W3W1s2 + W3W1W0s3*x
        NNxy_W1 = W3W0s2 + W3W1W0s3*y
        NNxy_W2 = W3W1W0s3
        NNxy_W3 = W[:,1]*W[:,0]*s2
        NNxy_W = torch.cat((NNxy_W0,NNxy_W1,NNxy_W2,NNxy_W3),0) # combine derivatives into a column vector
        # derivatives w.r.t. parameters of NNxx = sum(w3*w0^2*s2)
        W3W0W0s3 = W[:,3]*W[:,0].pow(2)*s3
        NNxx_W0 = 2*W3W0s2 + W3W0W0s3*x
        NNxx_W1 = W3W0W0s3*y
        NNxx_W2 = W3W0W0s3
        NNxx_W3 = W[:,0].pow(2)*s2
        NNxx_W = torch.cat((NNxx_W0,NNxx_W1,NNxx_W2,NNxx_W3),0) # combine derivatives into a column vector
        # derivatives w.r.t. parameters of NNyy = sum(w3*w1^2*s2)
        W3W1W1s3 = W[:,3]*W[:,1].pow(2)*s3
        NNyy_W0 = W3W1W1s3*x
        NNyy_W1 = 2*W3W1s2 + W3W1W1s3*y
        NNyy_W2 = W3W1W1s3
        NNyy_W3 = W[:,1].pow(2)*s2
        NNyy_W = torch.cat((NNyy_W0,NNyy_W1,NNyy_W2,NNyy_W3),0) # combine derivatives into a column vector
        # derivatives w.r.t. parameters of NNxxy = sum(w3*w1^2*s2)
        W3W1W0W0s4 = W[:,3]*W[:,1]*W[:,0].pow(2)*s3
        NNxxy_W0 = 2*W3W1W0s3 + W3W1W0W0s4*x
        NNxxy_W1 = W3W0W0s3 + W3W1W0W0s4*y
        NNxxy_W2 = W3W1W0W0s4
        NNxxy_W3 = W[:,1]*W[:,0].pow(2)*s3
        NNxxy_W = torch.cat((NNxxy_W0,NNxxy_W1,NNxxy_W2,NNxxy_W3),0) # combine derivatives into a column vector
        return NN, NNx, NNy, NNxy, NNxx, NNyy, NNxxy, NN_W, NNx_W, NNy_W, NNxy_W, NNxx_W, NNyy_W, NNxxy_W
    
def SolutionModel(x,y,W):
    # u(x,y) = B(x,y) + x(1-x)y[NN(x,y;w) - NN(x,1;w) - (d/dy)*NN(x,1;w)], where
    # B(x,y) = y[2sin(pi*x)]
    NN = NeuralNetwork(x,y,W,False)
    N1 = NeuralNetwork(x,torch.ones_like(x).unsqueeze(0),W,True)

#     B = 2*y*(torch.sin(math.pi*x)) 
#     mul = x*(1-x)*y

#     sol = B + mul*(NN - N1[0] - N1[2])
    sol = 2*y*torch.sin(math.pi*x) + x*(1-x)*y*(NN-N1[0]-N1[2])
    return sol

def RHS(x,y):
    return (2 - (math.pi**2) * y**2) * torch.sin(math.pi * x)


def PoissonEqSolutionModel(x,y,W):
    # computes the r = Laplacian[B(x,y) + x(1-x)y[NN(x,y;w) - NN(x,1;w) - (d/dy)*NN(x,1;w)]] - RightHandSide
    # and the gradient of r w.r.t parameters W
    NN, NNx, NNy, NNxy, NNxx, NNyy, NNxxy, NN_W, NNx_W, NNy_W, NNxy_W, NNxx_W, NNyy_W, NNxxy_W = NeuralNetwork(x,y,W,True)
    NN1, NNx1, NNy1, NNxy1, NNxx1, NNyy1, NNxxy1, NN_W1, NNx_W1, NNy_W1, NNxy_W1, NNxx_W1, NNyy_W1, NNxxy_W1 = NeuralNetwork(x,torch.ones_like(x).unsqueeze(0),W,True)

    Bxx = -2*y*(math.pi**2)*torch.sin(math.pi*x)
    Byy = 0
    C   = x*(1-x)*y
    Cx  = (1-2*x)*y
    Cy  = x*(1-x)
    Cxx = -2*y
    Cyy = 0
    
    uxx = Bxx + Cxx*(NN-NN1-NNy1) + 2*Cx*(NNx-NNx1-NNxy1) + C*(NNxx-NNxx1-NNxxy1)
    uyy = Byy + 2*Cy*NNy + C*NNyy
    
#     uxx = (-2*(math.pi**2)*y*torch.sin(math.pi*x)) + (-2)*y*(NN-NN1-NNy1) + y*(1-2*x)*(NNx-NNx1-NNxy1) + y*(1-2*x)*(NNx-NNx1-NNxy1) + y*(x-x**2)*(NNxx-NNxx1-NNxxy1)
#     uyy = 2*math.pi*y*torch.cos(math.pi*x) + y*(1-2*x)*(NN-NN1-NNy1) + y*(x-x**2)*(NNx-NNx1-NNxy1)
    
    res = uxx + uyy - RHS(x,y)
    
#     # TODO: this part is not fixed
#     B1 = x*(1-x)
#     B1x = 1-2*x
#     B1xx = -2.
#     B2 = y
#     B2y = 1
#     B2yy = 0
    
    dres_W = Cxx*(NN_W-NN_W1-NNy_W1) + 2*Cx*(NNx_W-NNx_W1-NNxy_W1) + C*(NNxx_W-NNxx_W1-NNxxy_W1) + 2*Cy*NNy_W + C*NNyy_W
#     dres_W = (B2*B1xx + B1*B2yy)*NN_W + 2*(B2*B1x*(NNx_W-NNx_W1-NNxy_W1) + B1*B2y*(NNy_W-NNy_W1-NNyy_W1)) + B2*B1*(NNxx_W-NNxx_W1-NNxxy_W1+NNyy_W-NNyy_W1-NNyyy_W1)
    return res, dres_W

# %%
# form the vector of residuals and the Jacobian matrix for the set of training points
def Residual_and_Jacobian(xy,W):
    # each row of xy corresponds to a training point
    Nxy = xy.size(dim=0) # the number of training points
    NW = W.numel() # total number of entries of W
    res = torch.zeros(Nxy,1) # vector of residuals
    Jac = torch.zeros(Nxy,NW) # Jacobian matrix
    for j in range(Nxy):
        r,dr_W = PoissonEqSolutionModel(xy[j,0],xy[j,1],W)
        res[j] = r
        Jac[j,:] = dr_W
    return res, Jac

# %%
# Levenverg-Marquardt
def Loss(r):
    return 0.5*torch.sum(r.pow(2)) # 0.5*sum(r^2)
    
def LevenbergMarquardt(Res_and_Jac,par,x):
    # minimizes loss = 0.5/n sum_{j=1}^n r_j^2(x)
    # constrained minimization problem solved at each step:
    # m(p) = grad^\top p + 0.5 p^\top Bmatr p --> min
    # subject to R - ||p|| >= 0
    # rho = [loss - loss(x + p)] / [loss - m(p)]
    
    # parameters for Levengerg-Marquardt
    RMAX = 1.;
    RMIN = 1e-12;
    RHO_GOOD = 0.75 # increase R is rho > RHO_GOOD
    RHO_BAD = 0.25 # decrease R is rho < RHO_BAD
    ETA = 0.01 # reject step if rho < ETA 
    ITER_MAX = 100
    TOL = 1.0e-6 # terminate when || grad loss || < tol
    
    # initialization
    r,J = Res_and_Jac(par,x)
    # print(r.size())
    # print(J.size())
    n = J.size(dim = 0) # the number of components of r
    d = J.size(dim = 1) # the number of variables
    lossvals = torch.zeros(ITER_MAX)
    gradnormvals = torch.zeros(ITER_MAX)
    lossvals[0] = Loss(r)
    Jtrans = torch.transpose(J,0,1)
    grad = torch.matmul(Jtrans,r) # grad = J^\top r
    Bmatr = torch.matmul(Jtrans,J) # Bmatr = J^\top J
    gradnorm = torch.linalg.norm(grad)
    gradnormvals[0] = gradnorm
    R = 0.2*RMAX # initial trust region radius
    print("iter 0: loss = ",lossvals[0]," gradnorm = ",gradnorm)
    # start iterations
    iter = 1
    print("Hi")
    while gradnorm > TOL and iter < ITER_MAX:
        # print(Jtrans.size())
        # print(J.size())
        # print(torch.eye(d).size())
        # print(torch.matmul(Jtrans,J).size())
        Bmatr = torch.matmul(Jtrans,J) # B = J^\top J
        p = -torch.linalg.lstsq(Bmatr,grad).solution # p = -Bmatr^{-1}grad
        norm_p = torch.linalg.norm(p)
        if norm_p > R:
            # solve grad^\top p + 0.5 p^\top Bmatr p --> min
            # subject to ||p|| = R
            gap = torch.abs(norm_p - R)
            iter_lam = 0
            lam_tol = 0.01*R
            lam = 1 # initial guess for lambda in the 1D constrained minimization problems
            while gap > lam_tol:
                B1 = Bmatr + lam*torch.eye(d) 
                C = torch.linalg.cholesky(B1) # B1 = C C^\top
                p = -torch.linalg.solve_triangular(torch.transpose(C,0,1), \
                     torch.linalg.solve_triangular(C,grad,upper = False),upper = True)
                norm_p = torch.linalg.norm(p)
                gap = torch.abs(norm_p - R)
                if gap > lam_tol:
                    q = torch.linalg.solve_triangular(C,p,upper = False)
                    norm_q = torch.linalg.norm(q)
                    lamnew = lam + (norm_p/norm_q).pow(2)*(norm_p-R)/R
                    if lamnew < 0:
                        lam = 0.5*lam
                    else:
                        lam = lamnew
                    iter_lam = iter_lam + 1
                    gap = torch.abs(norm_p - R)
            print("LM, iter ",iter,":", iter_lam," substeps")
        else:
            print("LM, iter ",iter,": steps to the model's minimum")
        # evaluate the progres
        # print("size of x: ",x.size())
        # print("size of p: ",p.size())
        xnew = x + p
        # print("size of xnew: ",xnew.size())
        rnew,Jnew = Res_and_Jac(par,xnew)  
        # print("rnew: ",rnew.size())
        # print("Jnew: ",Jnew.size())
        lossnew = Loss(rnew)
        rho = -(lossvals[iter-1] - lossnew)/(torch.sum(grad*p) + 0.5*sum(p*torch.matmul(Bmatr,p)))   
        # adjust the trust region radius
        if rho < RHO_BAD:
            R = torch.max(torch.tensor([RMIN,0.25*R]))
        elif rho > RHO_GOOD:
            R = torch.min(torch.tensor([RMAX,2.0*R]))                                       
        # accept or reject the step
        if rho > ETA:
            x = xnew
            r = rnew
            J = Jnew  
            Jtrans = torch.transpose(J,0,1)
            grad = torch.matmul(Jtrans,r)                                       
            gradnorm = torch.linalg.norm(grad)
        lossvals[iter] = lossnew
        gradnormvals[iter] = gradnorm
        print("LM, iter ",iter,": loss = ",lossvals[iter]," gradnorm = ",gradnorm," rho = ",rho," R = ",R)
        iter = iter + 1                                           
    return x,iter,lossvals[0:iter], gradnormvals[0:iter]

# %%
# train neural network
W,Niter,lossvals,gradnormvals = LevenbergMarquardt(Residual_and_Jacobian,xytrain,W)
# plot the loss and the norm of the gradient of the loss
plt.figure()
plt.plot(torch.arange(Niter),lossvals)
plt.title("Loss vs iter number")
plt.yscale("log")
plt.xlabel("iter number")
plt.figure()
plt.plot(np.arange(Niter),gradnormvals)
plt.title("Grad norm vs iter number")
plt.yscale("log")
plt.xlabel("iter number")
# Out:
# iter 0: loss =  tensor(662.6154)  gradnorm =  tensor(452.7545)
# Hi
# LM, iter  1 : 3  substeps
# LM, iter  1 : loss =  tensor(571.9926)  gradnorm =  tensor(462.2692)  rho =  tensor([1.0441])  R =  tensor(0.4000)
# LM, iter  2 : 3  substeps
# LM, iter  2 : loss =  tensor(391.0621)  gradnorm =  tensor(450.1230)  rho =  tensor([1.0858])  R =  tensor(0.8000)
# LM, iter  3 : 4  substeps
# LM, iter  3 : loss =  tensor(130.0752)  gradnorm =  tensor(210.1064)  rho =  tensor([1.0438])  R =  tensor(1.)
# LM, iter  4 : 2  substeps
# LM, iter  4 : loss =  tensor(84.3596)  gradnorm =  tensor(80.9970)  rho =  tensor([0.7675])  R =  tensor(1.)
# LM, iter  5 : 2  substeps
# LM, iter  5 : loss =  tensor(70.6857)  gradnorm =  tensor(163.2549)  rho =  tensor([0.6495])  R =  tensor(1.)
# LM, iter  6 : 3  substeps
# LM, iter  6 : loss =  tensor(24.0002)  gradnorm =  tensor(151.1896)  rho =  tensor([1.1711])  R =  tensor(1.)
# LM, iter  7 : 2  substeps
# LM, iter  7 : loss =  tensor(87.9512)  gradnorm =  tensor(151.1896)  rho =  tensor([-2.8804])  R =  tensor(0.2500)
# LM, iter  8 : 4  substeps
# LM, iter  8 : loss =  tensor(12.6755)  gradnorm =  tensor(63.0495)  rho =  tensor([4.6901])  R =  tensor(0.5000)
# LM, iter  9 : 3  substeps
# LM, iter  9 : loss =  tensor(4.0149)  gradnorm =  tensor(19.4630)  rho =  tensor([1.0197])  R =  tensor(1.)
# LM, iter  10 : 1  substeps
# LM, iter  10 : loss =  tensor(12.3703)  gradnorm =  tensor(19.4630)  rho =  tensor([-2.8836])  R =  tensor(0.2500)
# LM, iter  11 : 3  substeps
# LM, iter  11 : loss =  tensor(2.7597)  gradnorm =  tensor(12.9396)  rho =  tensor([5.3296])  R =  tensor(0.5000)
# LM, iter  12 : 2  substeps
# LM, iter  12 : loss =  tensor(3.0877)  gradnorm =  tensor(12.9396)  rho =  tensor([-0.3041])  R =  tensor(0.1250)
# LM, iter  13 : 2  substeps
# LM, iter  13 : loss =  tensor(2.4758)  gradnorm =  tensor(8.8527)  rho =  tensor([1.3849])  R =  tensor(0.2500)
# LM, iter  14 : 2  substeps
# LM, iter  14 : loss =  tensor(2.3804)  gradnorm =  tensor(21.2549)  rho =  tensor([0.1849])  R =  tensor(0.0625)
# LM, iter  15 : 2  substeps
# LM, iter  15 : loss =  tensor(2.0417)  gradnorm =  tensor(3.9314)  rho =  tensor([1.2594])  R =  tensor(0.1250)
# LM, iter  16 : 2  substeps
# LM, iter  16 : loss =  tensor(2.0079)  gradnorm =  tensor(10.0810)  rho =  tensor([0.1515])  R =  tensor(0.0312)
# LM, iter  17 : 2  substeps
# LM, iter  17 : loss =  tensor(1.8640)  gradnorm =  tensor(2.1399)  rho =  tensor([1.4283])  R =  tensor(0.0625)
# LM, iter  18 : 2  substeps
# LM, iter  18 : loss =  tensor(1.8138)  gradnorm =  tensor(4.7857)  rho =  tensor([0.4786])  R =  tensor(0.0625)
# LM, iter  19 : 2  substeps
# LM, iter  19 : loss =  tensor(1.7180)  gradnorm =  tensor(4.1967)  rho =  tensor([0.8572])  R =  tensor(0.1250)
# LM, iter  20 : 2  substeps
# LM, iter  20 : loss =  tensor(1.5618)  gradnorm =  tensor(7.8018)  rho =  tensor([0.7678])  R =  tensor(0.2500)
# LM, iter  21 : 2  substeps
# LM, iter  21 : loss =  tensor(1.1918)  gradnorm =  tensor(12.1865)  rho =  tensor([0.9500])  R =  tensor(0.5000)
# LM, iter  22 : 1  substeps
# LM, iter  22 : loss =  tensor(0.4828)  gradnorm =  tensor(11.5672)  rho =  tensor([1.1477])  R =  tensor(1.)
# LM, iter  23 : 3  substeps
# LM, iter  23 : loss =  tensor(1.6259)  gradnorm =  tensor(11.5672)  rho =  tensor([-2.8966])  R =  tensor(0.2500)
# LM, iter  24 : 2  substeps
# LM, iter  24 : loss =  tensor(0.4332)  gradnorm =  tensor(19.8106)  rho =  tensor([5.5359])  R =  tensor(0.5000)
# LM, iter  25 : 2  substeps
# LM, iter  25 : loss =  tensor(0.1359)  gradnorm =  tensor(10.3528)  rho =  tensor([0.8948])  R =  tensor(1.)
# LM, iter  26 : 5  substeps
# LM, iter  26 : loss =  tensor(5.3165)  gradnorm =  tensor(10.3528)  rho =  tensor([-40.7497])  R =  tensor(0.2500)
# LM, iter  27 : 3  substeps
# LM, iter  27 : loss =  tensor(0.2120)  gradnorm =  tensor(20.8228)  rho =  tensor([57.2877])  R =  tensor(0.5000)
# LM, iter  28 : 4  substeps
# LM, iter  28 : loss =  tensor(0.3885)  gradnorm =  tensor(20.8228)  rho =  tensor([-0.9351])  R =  tensor(0.1250)
# LM, iter  29 : 2  substeps
# LM, iter  29 : loss =  tensor(0.0844)  gradnorm =  tensor(8.2290)  rho =  tensor([1.7860])  R =  tensor(0.2500)
# LM, iter  30 : 3  substeps
# LM, iter  30 : loss =  tensor(0.0353)  gradnorm =  tensor(3.5517)  rho =  tensor([0.9351])  R =  tensor(0.5000)
# LM, iter  31 : 5  substeps
# LM, iter  31 : loss =  tensor(0.2136)  gradnorm =  tensor(3.5517)  rho =  tensor([-8.3938])  R =  tensor(0.1250)
# LM, iter  32 : 2  substeps
# LM, iter  32 : loss =  tensor(0.0406)  gradnorm =  tensor(5.2479)  rho =  tensor([15.7685])  R =  tensor(0.2500)
# LM, iter  33 : 4  substeps
# LM, iter  33 : loss =  tensor(0.0228)  gradnorm =  tensor(5.4369)  rho =  tensor([0.7228])  R =  tensor(0.2500)
# LM, iter  34 : 4  substeps
# LM, iter  34 : loss =  tensor(0.0306)  gradnorm =  tensor(5.4369)  rho =  tensor([-0.5728])  R =  tensor(0.0625)
# LM, iter  35 : 3  substeps
# LM, iter  35 : loss =  tensor(0.0147)  gradnorm =  tensor(0.6870)  rho =  tensor([1.6469])  R =  tensor(0.1250)
# LM, iter  36 : 4  substeps
# LM, iter  36 : loss =  tensor(0.0296)  gradnorm =  tensor(0.6870)  rho =  tensor([-3.5625])  R =  tensor(0.0312)
# LM, iter  37 : 1  substeps
# LM, iter  37 : loss =  tensor(0.0138)  gradnorm =  tensor(1.7874)  rho =  tensor([7.4646])  R =  tensor(0.0625)
# LM, iter  38 : 2  substeps
# LM, iter  38 : loss =  tensor(0.0189)  gradnorm =  tensor(1.7874)  rho =  tensor([-1.7718])  R =  tensor(0.0156)
# LM, iter  39 : 1  substeps
# LM, iter  39 : loss =  tensor(0.0125)  gradnorm =  tensor(1.1504)  rho =  tensor([3.4718])  R =  tensor(0.0312)
# LM, iter  40 : 1  substeps
# LM, iter  40 : loss =  tensor(0.0120)  gradnorm =  tensor(1.4510)  rho =  tensor([0.3436])  R =  tensor(0.0312)
# LM, iter  41 : 1  substeps
# LM, iter  41 : loss =  tensor(0.0104)  gradnorm =  tensor(0.8734)  rho =  tensor([0.8145])  R =  tensor(0.0625)
# LM, iter  42 : 2  substeps
# LM, iter  42 : loss =  tensor(0.0130)  gradnorm =  tensor(0.8734)  rho =  tensor([-1.4758])  R =  tensor(0.0156)
# LM, iter  43 : 1  substeps
# LM, iter  43 : loss =  tensor(0.0096)  gradnorm =  tensor(0.3256)  rho =  tensor([4.1027])  R =  tensor(0.0312)
# LM, iter  44 : 1  substeps
# LM, iter  44 : loss =  tensor(0.0106)  gradnorm =  tensor(0.3256)  rho =  tensor([-1.3826])  R =  tensor(0.0078)
# LM, iter  45 : 2  substeps
# LM, iter  45 : loss =  tensor(0.0094)  gradnorm =  tensor(0.3179)  rho =  tensor([5.3758])  R =  tensor(0.0156)
# LM, iter  46 : 1  substeps
# LM, iter  46 : loss =  tensor(0.0093)  gradnorm =  tensor(0.8928)  rho =  tensor([0.1229])  R =  tensor(0.0039)
# LM, iter  47 : 2  substeps
# LM, iter  47 : loss =  tensor(0.0089)  gradnorm =  tensor(0.2476)  rho =  tensor([0.9125])  R =  tensor(0.0078)
# LM, iter  48 : 1  substeps
# LM, iter  48 : loss =  tensor(0.0087)  gradnorm =  tensor(0.4496)  rho =  tensor([0.6319])  R =  tensor(0.0078)
# LM, iter  49 : 2  substeps
# LM, iter  49 : loss =  tensor(0.0085)  gradnorm =  tensor(0.2727)  rho =  tensor([0.9590])  R =  tensor(0.0156)
# LM, iter  50 : 1  substeps
# LM, iter  50 : loss =  tensor(0.0084)  gradnorm =  tensor(0.8378)  rho =  tensor([0.1403])  R =  tensor(0.0039)
# LM, iter  51 : 2  substeps
# LM, iter  51 : loss =  tensor(0.0080)  gradnorm =  tensor(0.2613)  rho =  tensor([0.8911])  R =  tensor(0.0078)
# LM, iter  52 : 1  substeps
# LM, iter  52 : loss =  tensor(0.0079)  gradnorm =  tensor(0.4597)  rho =  tensor([0.5740])  R =  tensor(0.0078)
# LM, iter  53 : 2  substeps
# LM, iter  53 : loss =  tensor(0.0076)  gradnorm =  tensor(0.2766)  rho =  tensor([0.9390])  R =  tensor(0.0156)
# LM, iter  54 : 1  substeps
# LM, iter  54 : loss =  tensor(0.0076)  gradnorm =  tensor(0.8474)  rho =  tensor([0.0531])  R =  tensor(0.0039)
# LM, iter  55 : 2  substeps
# LM, iter  55 : loss =  tensor(0.0072)  gradnorm =  tensor(0.2814)  rho =  tensor([0.8766])  R =  tensor(0.0078)
# LM, iter  56 : 1  substeps
# LM, iter  56 : loss =  tensor(0.0071)  gradnorm =  tensor(0.4716)  rho =  tensor([0.5251])  R =  tensor(0.0078)
# LM, iter  57 : 2  substeps
# LM, iter  57 : loss =  tensor(0.0068)  gradnorm =  tensor(0.2711)  rho =  tensor([0.9257])  R =  tensor(0.0156)
# LM, iter  58 : 1  substeps
# LM, iter  58 : loss =  tensor(0.0068)  gradnorm =  tensor(0.2711)  rho =  tensor([-0.0271])  R =  tensor(0.0039)
# LM, iter  59 : 2  substeps
# LM, iter  59 : loss =  tensor(0.0067)  gradnorm =  tensor(0.0966)  rho =  tensor([1.0427])  R =  tensor(0.0078)
# LM, iter  60 : 1  substeps
# LM, iter  60 : loss =  tensor(0.0066)  gradnorm =  tensor(0.4427)  rho =  tensor([0.5195])  R =  tensor(0.0078)
# LM, iter  61 : 2  substeps
# LM, iter  61 : loss =  tensor(0.0064)  gradnorm =  tensor(0.2739)  rho =  tensor([0.9052])  R =  tensor(0.0156)
# LM, iter  62 : 1  substeps
# LM, iter  62 : loss =  tensor(0.0064)  gradnorm =  tensor(0.2739)  rho =  tensor([-0.0139])  R =  tensor(0.0039)
# LM, iter  63 : 2  substeps
# LM, iter  63 : loss =  tensor(0.0063)  gradnorm =  tensor(0.0924)  rho =  tensor([0.9888])  R =  tensor(0.0078)
# LM, iter  64 : 1  substeps
# LM, iter  64 : loss =  tensor(0.0062)  gradnorm =  tensor(0.4427)  rho =  tensor([0.4811])  R =  tensor(0.0078)
# LM, iter  65 : 2  substeps
# LM, iter  65 : loss =  tensor(0.0060)  gradnorm =  tensor(0.2656)  rho =  tensor([0.8979])  R =  tensor(0.0156)
# LM, iter  66 : 1  substeps
# LM, iter  66 : loss =  tensor(0.0060)  gradnorm =  tensor(0.2656)  rho =  tensor([-0.0471])  R =  tensor(0.0039)
# LM, iter  67 : 2  substeps
# LM, iter  67 : loss =  tensor(0.0059)  gradnorm =  tensor(0.0914)  rho =  tensor([1.0642])  R =  tensor(0.0078)
# LM, iter  68 : 1  substeps
# LM, iter  68 : loss =  tensor(0.0058)  gradnorm =  tensor(0.4391)  rho =  tensor([0.4483])  R =  tensor(0.0078)
# LM, iter  69 : 2  substeps
# LM, iter  69 : loss =  tensor(0.0056)  gradnorm =  tensor(0.2551)  rho =  tensor([0.8895])  R =  tensor(0.0156)
# LM, iter  70 : 1  substeps
# LM, iter  70 : loss =  tensor(0.0056)  gradnorm =  tensor(0.2551)  rho =  tensor([-0.0765])  R =  tensor(0.0039)
# LM, iter  71 : 2  substeps
# LM, iter  71 : loss =  tensor(0.0055)  gradnorm =  tensor(0.0915)  rho =  tensor([1.1239])  R =  tensor(0.0078)
# LM, iter  72 : 1  substeps
# LM, iter  72 : loss =  tensor(0.0054)  gradnorm =  tensor(0.4335)  rho =  tensor([0.4148])  R =  tensor(0.0078)
# LM, iter  73 : 1  substeps
# LM, iter  73 : loss =  tensor(0.0052)  gradnorm =  tensor(0.2466)  rho =  tensor([0.8757])  R =  tensor(0.0156)
# LM, iter  74 : 1  substeps
# LM, iter  74 : loss =  tensor(0.0052)  gradnorm =  tensor(0.2466)  rho =  tensor([-0.0883])  R =  tensor(0.0039)
# LM, iter  75 : 2  substeps
# LM, iter  75 : loss =  tensor(0.0051)  gradnorm =  tensor(0.0949)  rho =  tensor([1.1261])  R =  tensor(0.0078)
# LM, iter  76 : 1  substeps
# LM, iter  76 : loss =  tensor(0.0051)  gradnorm =  tensor(0.4258)  rho =  tensor([0.3790])  R =  tensor(0.0078)
# LM, iter  77 : 1  substeps
# LM, iter  77 : loss =  tensor(0.0048)  gradnorm =  tensor(0.2313)  rho =  tensor([0.8627])  R =  tensor(0.0156)
# LM, iter  78 : 1  substeps
# LM, iter  78 : loss =  tensor(0.0049)  gradnorm =  tensor(0.2313)  rho =  tensor([-0.1134])  R =  tensor(0.0039)
# LM, iter  79 : 2  substeps
# LM, iter  79 : loss =  tensor(0.0048)  gradnorm =  tensor(0.1017)  rho =  tensor([1.1576])  R =  tensor(0.0078)
# LM, iter  80 : 1  substeps
# LM, iter  80 : loss =  tensor(0.0047)  gradnorm =  tensor(0.4147)  rho =  tensor([0.3443])  R =  tensor(0.0078)
# LM, iter  81 : 1  substeps
# LM, iter  81 : loss =  tensor(0.0045)  gradnorm =  tensor(0.2150)  rho =  tensor([0.8437])  R =  tensor(0.0156)
# LM, iter  82 : 1  substeps
# LM, iter  82 : loss =  tensor(0.0045)  gradnorm =  tensor(0.2150)  rho =  tensor([-0.1382])  R =  tensor(0.0039)
# LM, iter  83 : 2  substeps
# LM, iter  83 : loss =  tensor(0.0044)  gradnorm =  tensor(0.1139)  rho =  tensor([1.1746])  R =  tensor(0.0078)
# LM, iter  84 : 1  substeps
# LM, iter  84 : loss =  tensor(0.0044)  gradnorm =  tensor(0.4005)  rho =  tensor([0.3080])  R =  tensor(0.0078)
# LM, iter  85 : 1  substeps
# LM, iter  85 : loss =  tensor(0.0042)  gradnorm =  tensor(0.2001)  rho =  tensor([0.8150])  R =  tensor(0.0156)
# LM, iter  86 : 1  substeps
# LM, iter  86 : loss =  tensor(0.0042)  gradnorm =  tensor(0.2001)  rho =  tensor([-0.1669])  R =  tensor(0.0039)
# LM, iter  87 : 2  substeps
# LM, iter  87 : loss =  tensor(0.0041)  gradnorm =  tensor(0.1328)  rho =  tensor([1.1827])  R =  tensor(0.0078)
# LM, iter  88 : 1  substeps
# LM, iter  88 : loss =  tensor(0.0041)  gradnorm =  tensor(0.3830)  rho =  tensor([0.2696])  R =  tensor(0.0078)
# LM, iter  89 : 1  substeps
# LM, iter  89 : loss =  tensor(0.0039)  gradnorm =  tensor(0.1913)  rho =  tensor([0.7709])  R =  tensor(0.0156)
# LM, iter  90 : 1  substeps
# LM, iter  90 : loss =  tensor(0.0040)  gradnorm =  tensor(0.1913)  rho =  tensor([-0.2061])  R =  tensor(0.0039)
# LM, iter  91 : 2  substeps
# LM, iter  91 : loss =  tensor(0.0038)  gradnorm =  tensor(0.1594)  rho =  tensor([1.1916])  R =  tensor(0.0078)
# LM, iter  92 : 1  substeps
# LM, iter  92 : loss =  tensor(0.0038)  gradnorm =  tensor(0.3626)  rho =  tensor([0.2284])  R =  tensor(0.0020)
# LM, iter  93 : 2  substeps
# LM, iter  93 : loss =  tensor(0.0037)  gradnorm =  tensor(0.2758)  rho =  tensor([0.5513])  R =  tensor(0.0020)
# LM, iter  94 : 2  substeps
# LM, iter  94 : loss =  tensor(0.0037)  gradnorm =  tensor(0.0789)  rho =  tensor([0.9646])  R =  tensor(0.0039)
# LM, iter  95 : 2  substeps
# LM, iter  95 : loss =  tensor(0.0036)  gradnorm =  tensor(0.1610)  rho =  tensor([0.6419])  R =  tensor(0.0039)
# LM, iter  96 : 2  substeps
# LM, iter  96 : loss =  tensor(0.0036)  gradnorm =  tensor(0.1082)  rho =  tensor([0.7493])  R =  tensor(0.0039)
# LM, iter  97 : 2  substeps
# LM, iter  97 : loss =  tensor(0.0035)  gradnorm =  tensor(0.0993)  rho =  tensor([0.7433])  R =  tensor(0.0039)
# LM, iter  98 : 2  substeps
# LM, iter  98 : loss =  tensor(0.0035)  gradnorm =  tensor(0.1025)  rho =  tensor([0.7261])  R =  tensor(0.0039)
# LM, iter  99 : 2  substeps
# LM, iter  99 : loss =  tensor(0.0034)  gradnorm =  tensor(0.1049)  rho =  tensor([0.7056])  R =  tensor(0.0039)
# Text(0.5, 0, 'iter number')

# %%
# test the solution
sol_test = torch.zeros(npt2,npt2)
Ntest = torch.numel(sol_test)
for i in range(npt2):
    for j in range(npt2):
        sol_test[i,j] = SolutionModel(xtest_grid[i,j],ytest_grid[i,j],W)
plt.figure()
plt.contour(xtest_grid,ytest_grid,sol_test,torch.arange(sol_min,sol_max,0.1*(sol_max-sol_min)))   
plt.colorbar()
plt.title("Computed Solution")
# compare with the exact solution
error = torch.abs(sol_test - sol_exact)
error_vector = torch.reshape(error,(Ntest,1))
error_max = torch.max(error_vector)
plt.figure()
plt.contour(xtest_grid,ytest_grid,error,torch.arange(0.,error_max,error_max*0.1))  
plt.colorbar() 
plt.title("Error")
print("Max error = ",torch.max(error_vector))
print("Mean error = ",torch.mean(error_vector))
print("RMS error = ",torch.sqrt(torch.mean(error_vector.pow(2))))
# Out:
# Max error =  tensor(0.0008)
# Mean error =  tensor(0.0002)
# RMS error =  tensor(0.0003)
